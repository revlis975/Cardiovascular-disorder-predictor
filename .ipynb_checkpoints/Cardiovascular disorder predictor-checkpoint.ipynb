# %%
#importing required libraries
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline

# %%
df=pd.read_csv('heart.csv')
df.head(5)
df.shape
# Out:
# (303, 14)

# %% [markdown]
# It's a clean, easy to understand set of data. However, the meaning of some of the column headers are not obvious. Here's what they mean,
#
# 1.age: The person's age in years
#
# 2.sex: The person's sex (1 = male, 0 = female)
#
# 3.cp: The chest pain experienced (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic)
#
# 4.trestbps: The person's resting blood pressure (mm Hg on admission to the hospital)
#
# 5.chol: The person's cholesterol measurement in mg/dl
#
# 6.fbs: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
#
# 7.restecg: Resting electrocardiographic measurement (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable or definite left ventricular hypertrophy by Estes' criteria)
#
# 8.thalach: The person's maximum heart rate achieved
#
# 9.exang: Exercise induced angina (1 = yes; 0 = no)
#
# 10.oldpeak: ST depression induced by exercise relative to rest ('ST' relates to positions on the ECG plot. See more here)
#
# 11.slope: the slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
#
# 12.ca: The number of major vessels (0-3)
#
# 13.thal: A blood disorder called thalassemia (3 = normal; 6 = fixed defect; 7 = reversable defect)
#
# 14.target: Heart disease (0 = no, 1 = yes)

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
df.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype=object)

# %%
# chest_pain=pd.get_dummies(df['cp'],prefix='cp',drop_first=True)
# df=pd.concat([df,chest_pain],axis=1)
# df.drop(['cp'],axis=1,inplace=True)
# sp=pd.get_dummies(df['slope'],prefix='slope')
# th=pd.get_dummies(df['thal'],prefix='thal')
# rest_ecg=pd.get_dummies(df['restecg'],prefix='restecg')
# frames=[df,sp,th,rest_ecg]
# df=pd.concat(frames,axis=1)
# df.drop(['slope','thal','restecg'],axis=1,inplace=True)

# %%
X = df.drop(['target'], axis = 1)
y = df.target.values

# %%
#splitting the data to training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
#standard preprocessing for easy training of the model
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)
X_train
# Out:
# array([[-1.32773282, -1.43641607,  0.98584243, ..., -0.66169316,
#         -0.70710678, -0.46472917],
#        [ 1.24903178, -1.43641607,  0.98584243, ..., -0.66169316,
#          0.26516504, -0.46472917],
#        [ 0.35276583,  0.69617712,  0.98584243, ...,  0.95577901,
#         -0.70710678, -0.46472917],
#        ...,
#        [ 0.12869935,  0.69617712,  1.94013791, ..., -0.66169316,
#         -0.70710678,  1.14190596],
#        [-0.87959984,  0.69617712,  0.98584243, ...,  0.95577901,
#         -0.70710678, -0.46472917],
#        [ 0.35276583,  0.69617712,  0.03154696, ..., -0.66169316,
#         -0.70710678, -0.46472917]])

# %%
#importing keras layers and models
import keras
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.layers import Dense

# %%
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(keras.layers.Dense(13, activation = 'relu', kernel_initializer = 'uniform', input_dim = 13))

# Adding the second hidden layer
classifier.add(Dense(13, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Epoch 1/100
# 25/25 [==============================] - 2s 3ms/step - loss: 0.6931 - accuracy: 0.5455
# Epoch 2/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.6912 - accuracy: 0.5620
# Epoch 3/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6809 - accuracy: 0.7603
# Epoch 4/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.6463 - accuracy: 0.8182
# Epoch 5/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.5749 - accuracy: 0.8223
# Epoch 6/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.4941 - accuracy: 0.8347
# Epoch 7/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.4244 - accuracy: 0.8347
# Epoch 8/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3859 - accuracy: 0.8347
# Epoch 9/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3637 - accuracy: 0.8430
# Epoch 10/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3538 - accuracy: 0.8512
# Epoch 11/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3477 - accuracy: 0.8430
# Epoch 12/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3436 - accuracy: 0.8471
# Epoch 13/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3391 - accuracy: 0.8512
# Epoch 14/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3379 - accuracy: 0.8554
# Epoch 15/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3349 - accuracy: 0.8554
# Epoch 16/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3340 - accuracy: 0.8554
# Epoch 17/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3327 - accuracy: 0.8595
# Epoch 18/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3297 - accuracy: 0.8636
# Epoch 19/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3284 - accuracy: 0.8636
# Epoch 20/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3261 - accuracy: 0.8678
# Epoch 21/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3250 - accuracy: 0.8719
# Epoch 22/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3238 - accuracy: 0.8719
# Epoch 23/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3218 - accuracy: 0.8678
# Epoch 24/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3203 - accuracy: 0.8678
# Epoch 25/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3188 - accuracy: 0.8719
# Epoch 26/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3177 - accuracy: 0.8760
# Epoch 27/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3163 - accuracy: 0.8719
# Epoch 28/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3138 - accuracy: 0.8719
# Epoch 29/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3144 - accuracy: 0.8760
# Epoch 30/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.3135 - accuracy: 0.8802
# Epoch 31/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3118 - accuracy: 0.8802
# Epoch 32/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3095 - accuracy: 0.8802
# Epoch 33/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3085 - accuracy: 0.8802
# Epoch 34/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3078 - accuracy: 0.8843
# Epoch 35/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3069 - accuracy: 0.8802
# Epoch 36/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3048 - accuracy: 0.8843
# Epoch 37/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3035 - accuracy: 0.8843
# Epoch 38/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.3025 - accuracy: 0.8884
# Epoch 39/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3017 - accuracy: 0.8926
# Epoch 40/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.3005 - accuracy: 0.8884
# Epoch 41/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2991 - accuracy: 0.8884
# Epoch 42/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2987 - accuracy: 0.8843
# Epoch 43/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2966 - accuracy: 0.8884
# Epoch 44/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2959 - accuracy: 0.8843
# Epoch 45/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2938 - accuracy: 0.8843
# Epoch 46/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2925 - accuracy: 0.8926
# Epoch 47/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2917 - accuracy: 0.8884
# Epoch 48/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2916 - accuracy: 0.8926
# Epoch 49/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2890 - accuracy: 0.8884
# Epoch 50/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2900 - accuracy: 0.8843
# Epoch 51/100
# 25/25 [==============================] - 0s 5ms/step - loss: 0.2869 - accuracy: 0.8843
# Epoch 52/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2871 - accuracy: 0.8843
# Epoch 53/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2847 - accuracy: 0.8843
# Epoch 54/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2849 - accuracy: 0.8843
# Epoch 55/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2828 - accuracy: 0.8967
# Epoch 56/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2823 - accuracy: 0.8967
# Epoch 57/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2816 - accuracy: 0.8967
# Epoch 58/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2814 - accuracy: 0.8967
# Epoch 59/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2793 - accuracy: 0.8967
# Epoch 60/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2806 - accuracy: 0.8967
# Epoch 61/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2783 - accuracy: 0.9008
# Epoch 62/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2771 - accuracy: 0.9008
# Epoch 63/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2754 - accuracy: 0.8967
# Epoch 64/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2741 - accuracy: 0.9008
# Epoch 65/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2730 - accuracy: 0.9008
# Epoch 66/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2720 - accuracy: 0.9008
# Epoch 67/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2715 - accuracy: 0.9008
# Epoch 68/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2704 - accuracy: 0.9008
# Epoch 69/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2694 - accuracy: 0.9008
# Epoch 70/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2688 - accuracy: 0.8926
# Epoch 71/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2675 - accuracy: 0.9008
# Epoch 72/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2662 - accuracy: 0.9050
# Epoch 73/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2655 - accuracy: 0.8926
# Epoch 74/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2636 - accuracy: 0.9050
# Epoch 75/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2612 - accuracy: 0.9091
# Epoch 76/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2609 - accuracy: 0.9132
# Epoch 77/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2613 - accuracy: 0.9174
# Epoch 78/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2591 - accuracy: 0.9132
# Epoch 79/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2580 - accuracy: 0.9132
# Epoch 80/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2562 - accuracy: 0.9132
# Epoch 81/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2549 - accuracy: 0.9050
# Epoch 82/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2537 - accuracy: 0.9174
# Epoch 83/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2540 - accuracy: 0.9174
# Epoch 84/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2520 - accuracy: 0.9174
# Epoch 85/100
# 25/25 [==============================] - 0s 2ms/step - loss: 0.2510 - accuracy: 0.9132
# Epoch 86/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2497 - accuracy: 0.9132
# Epoch 87/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2532 - accuracy: 0.9132
# Epoch 88/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2490 - accuracy: 0.9091
# Epoch 89/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2458 - accuracy: 0.9132
# Epoch 90/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2445 - accuracy: 0.9132
# Epoch 91/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2435 - accuracy: 0.9174
# Epoch 92/100
# 25/25 [==============================] - 0s 4ms/step - loss: 0.2417 - accuracy: 0.9132
# Epoch 93/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2503 - accuracy: 0.91 - 0s 3ms/step - loss: 0.2403 - accuracy: 0.9215
# Epoch 94/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2396 - accuracy: 0.9215
# Epoch 95/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2378 - accuracy: 0.9132
# Epoch 96/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2386 - accuracy: 0.9132
# Epoch 97/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2355 - accuracy: 0.9215
# Epoch 98/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2339 - accuracy: 0.9215
# Epoch 99/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2314 - accuracy: 0.9174
# Epoch 100/100
# 25/25 [==============================] - 0s 3ms/step - loss: 0.2305 - accuracy: 0.9215

# %%
# Predicting the Test set results
X_user = pd.DataFrame(
    {'age': 75,
     'sex': 1,
     'cp': 0,
     'trestbps': 140,
     'chol': 192,
     'fbs': 0,
     'restecg': 1,
     'thalach': 148,
     'exang': 0,
     'oldpeak': 0.4,
     'slope': 1,
     'ca': 0,
     'thal': 1
    },index=[0])
# chest_pain=pd.get_dummies(X_user['cp'],prefix='cp',drop_first=True)
# X_user=pd.concat([X_user,chest_pain],axis=1)
# X_user.drop(['cp'],axis=1,inplace=True)
# sp=pd.get_dummies(X_user['slope'],prefix='slope')
# th=pd.get_dummies(X_user['thal'],prefix='thal')
# rest_ecg=pd.get_dummies(X_user['restecg'],prefix='restecg')
# frames=[X_user,sp,th,rest_ecg]
# X_user=pd.concat(frames,axis=1)
# X_user.drop(['slope','thal','restecg'],axis=1,inplace=True)
# X_user = sc.transform(X_test)
# y_pred = classifier.predict(X_test)
# print(float(y_pred[0]))
# print(int(y_pred[0][0]))

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
y_pred = classifier.predict(X_test)
cm = confusion_matrix(y_test, y_pred.round())
sns.heatmap(cm,annot=True,cmap="Blues",fmt="d",cbar=False)
# accuracy score

from sklearn.metrics import accuracy_score
ac=accuracy_score(y_test, y_pred.round())
print('accuracy of the model: ',ac)
# print(y_pred)
# print(y_test)
# print("F-1 score for the above algorithm: {}".format(f1_score(y_test, y_pred, average='weighted')))
# Out:
# accuracy of the model:  0.9016393442622951

# %%
classifier.save('C:/Users/HP/SC project')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6676dcf091b4> in <module>
# ----> 1 classifier.save('C:/Users/HP/SC project')
#
# NameError: name 'classifier' is not defined

# %%
df
